# %% [markdown]
# # Lab-Data-Manipulation (PART-1)

# %%
import pandas as pd

# %% [markdown]
# # Context
#
# For this lab you'll use a dataset for UFO observations. The objective is to exercise the manipulation of a dataframe, so we'll use the tools we've learned about `reading`, `renaming`, `selecting specific columns`, `filtering based on conditions` and `merging` dataframes to try to better understand our dataset and store an enriched version of our dataset at the end.
#
# Good Luck.

# %% [markdown]
# variable	|class|	description
# ------------|-----|-------------
# date_time	|datetime (mdy h:m)	| Date time sighting occurred
# city_area	|character	        | City or area of sighting
# state	    |character          |	state/region of sighting
# country	    |character          |	Country of sighting
# ufo_shape	|character          |	UFO Shape
# encounter_length	|double     |	Encounter length in seconds
# described_encounter_length	|character |	Encounter length as described (eg 1 hour, etc)
# description	|character          |	Description of encounter
# date_documented	|character      |	Date documented
# latitude	|double             |	Latitude
# longitude	|double             |	Longitude

# %% [markdown]
# ## Read the dataset and store it in a dataframe called `ufo`
#
# Pay attention at the file separator.

# %%
ufo = pd.read_csv('C:/Users/AlexandreH/Desktop/Ironhack - Labs and projects/Week 2/Day 3 - Data Manipulation/data/ufo.csv', sep =';')
ufo
# Out:
#        Unnamed: 0        date  year  month  day         date_time  \
# 0               0  1949-10-10  1949     10   10  10/10/1949 20:30
# 1               1  1949-10-10  1949     10   10  10/10/1949 21:00
# 2               2  1955-10-10  1955     10   10  10/10/1955 17:00
# 3               3  1956-10-10  1956     10   10  10/10/1956 21:00
# 4               4  1960-10-10  1960     10   10  10/10/1960 20:00
# ...           ...         ...   ...    ...  ...               ...
# 80327       80327  2013-09-09  2013      9    9    9/9/2013 21:15
# 80328       80328  2013-09-09  2013      9    9    9/9/2013 22:00
# 80329       80329  2013-09-09  2013      9    9    9/9/2013 22:00
# 80330       80330  2013-09-09  2013      9    9    9/9/2013 22:20
# 80331       80331  2013-09-09  2013      9    9    9/9/2013 23:00
#
#                   city_area state country ufo_shape  encounter_length  \
# 0                san marcos    tx      us  cylinder            2700.0
# 1              lackland afb    tx     NaN     light            7200.0
# 2      chester (uk/england)   NaN      gb    circle              20.0
# 3                      edna    tx      us    circle              20.0
# 4                   kaneohe    hi      us     light             900.0
# ...                     ...   ...     ...       ...               ...
# 80327             nashville    tn      us     light             600.0
# 80328                 boise    id      us    circle            1200.0
# 80329                  napa    ca      us     other            1200.0
# 80330                vienna    va      us    circle               5.0
# 80331                edmond    ok      us     cigar            1020.0
#
#       described_encounter_length  \
# 0                     45 minutes
# 1                        1-2 hrs
# 2                     20 seconds
# 3                       1/2 hour
# 4                     15 minutes
# ...                          ...
# 80327                 10 minutes
# 80328                 20 minutes
# 80329                       hour
# 80330                  5 seconds
# 80331                 17 minutes
#
#                                              description date_documented  \
# 0      This event took place in early fall around 194...       4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3      My older brother and twin sister were leaving ...       1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
# ...                                                  ...             ...
# 80327  Round from the distance/slowly changing colors...       9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...       9/30/2013
# 80329                                       Napa UFO&#44       9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...       9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...       9/30/2013
#
#         latitude   longitude
# 0      29.883056  -97.941111
# 1      29.384210  -98.581082
# 2      53.200000   -2.916667
# 3      28.978333  -96.645833
# 4      21.418056 -157.803611
# ...          ...         ...
# 80327  36.165833  -86.784444
# 80328  43.613611 -116.202500
# 80329  38.297222 -122.284444
# 80330  38.901111  -77.265556
# 80331  35.652778  -97.477778
#
# [80332 rows x 16 columns]

# %%
print(ufo.shape)
# Out:
# (80332, 16)

# %% [markdown]
# ## Check the first 6 columns of the dataframe

# %%
ufo.columns
#ufo[['date','year','month','day','date_time','city_area']]
# Out:
# Index(['Unnamed: 0', 'date', 'year', 'month', 'day', 'date_time', 'city_area',
#        'state', 'country', 'ufo_shape', 'encounter_length',
#        'described_encounter_length', 'description', 'date_documented',
#        'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# ## Check the shape of your dataframe to see how many rows and columns it has

# %%
ufo.shape

#lines 80332, columns 16
# Out:
# (80332, 16)

# %% [markdown]
# ## Bring the date information to the beginning of the dataframe
#
# If you check the dataframe columns, there are some information of the date at the end of the dataframe. For this task, you should reorder the columns in a way that the first few columns all show the date information.
#
# *Hint: Use the ufo.columns to see all the column names you have.

# %%
ufo[0:6]
# Out:
#          date  year  month  day         date_time date_documented  \
# 0  1949-10-10  1949     10   10  10/10/1949 20:30       4/27/2004
# 1  1949-10-10  1949     10   10  10/10/1949 21:00      12/16/2005
# 2  1955-10-10  1955     10   10  10/10/1955 17:00       1/21/2008
# 3  1956-10-10  1956     10   10  10/10/1956 21:00       1/17/2004
# 4  1960-10-10  1960     10   10  10/10/1960 20:00       1/22/2004
# 5  1961-10-10  1961     10   10  10/10/1961 19:00       4/27/2007
#
#               city_area state country ufo_shape  encounter_length  \
# 0            san marcos    tx      us  cylinder            2700.0
# 1          lackland afb    tx     NaN     light            7200.0
# 2  chester (uk/england)   NaN      gb    circle              20.0
# 3                  edna    tx      us    circle              20.0
# 4               kaneohe    hi      us     light             900.0
# 5               bristol    tn      us    sphere             300.0
#
#   described_encounter_length  \
# 0                 45 minutes
# 1                    1-2 hrs
# 2                 20 seconds
# 3                   1/2 hour
# 4                 15 minutes
# 5                  5 minutes
#
#                                          description   latitude   longitude
# 0  This event took place in early fall around 194...  29.883056  -97.941111
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  29.384210  -98.581082
# 2  Green/Orange circular disc over Chester&#44 En...  53.200000   -2.916667
# 3  My older brother and twin sister were leaving ...  28.978333  -96.645833
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  21.418056 -157.803611
# 5  My father is now 89 my brother 52 the girl wit...  36.595000  -82.188889

# %%
column_order = ['date', 'year', 'month', 'day', 'date_time','date_documented','city_area','state', 'country', 'ufo_shape', 'encounter_length','described_encounter_length', 'description', 'latitude', 'longitude']
ufo = ufo[column_order]

# %% [markdown]
# ## Just check if you did it the right way. Take a look at the head of the dataframe again and see if the `ufo` dataframe now is reordered.

# %%
ufo.head()
# Out:
#          date  year  month  day         date_time date_documented  \
# 0  1949-10-10  1949     10   10  10/10/1949 20:30       4/27/2004
# 1  1949-10-10  1949     10   10  10/10/1949 21:00      12/16/2005
# 2  1955-10-10  1955     10   10  10/10/1955 17:00       1/21/2008
# 3  1956-10-10  1956     10   10  10/10/1956 21:00       1/17/2004
# 4  1960-10-10  1960     10   10  10/10/1960 20:00       1/22/2004
#
#               city_area state country ufo_shape  encounter_length  \
# 0            san marcos    tx      us  cylinder            2700.0
# 1          lackland afb    tx     NaN     light            7200.0
# 2  chester (uk/england)   NaN      gb    circle              20.0
# 3                  edna    tx      us    circle              20.0
# 4               kaneohe    hi      us     light             900.0
#
#   described_encounter_length  \
# 0                 45 minutes
# 1                    1-2 hrs
# 2                 20 seconds
# 3                   1/2 hour
# 4                 15 minutes
#
#                                          description   latitude   longitude
# 0  This event took place in early fall around 194...  29.883056  -97.941111
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  29.384210  -98.581082
# 2  Green/Orange circular disc over Chester&#44 En...  53.200000   -2.916667
# 3  My older brother and twin sister were leaving ...  28.978333  -96.645833
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  21.418056 -157.803611

# %% [markdown]
# ## Select a piece of your dataframe. Create a new dataframe called `ufo_vars` and select only the following columns of the `ufo` dataframe.
#
# `year`, `month`, `state`, `country`, `ufo_shape`, `encounter_length`

# %%
ufo_vars = ufo[['year', 'month', 'state', 'country', 'ufo_shape', 'encounter_length']]

# %% [markdown]
# Perform a *.head()* on your result to check if you did it right.

# %%
ufo_vars.head()
# Out:
#    year  month state country ufo_shape  encounter_length
# 0  1949     10    tx      us  cylinder            2700.0
# 1  1949     10    tx     NaN     light            7200.0
# 2  1955     10   NaN      gb    circle              20.0
# 3  1956     10    tx      us    circle              20.0
# 4  1960     10    hi      us     light             900.0

# %% [markdown]
# ## Rename the variable `encounter_length` to `encounter_seconds`. Keep using the `ufo_vars` dataset for the following tasks, unless specifically specified.
#
# Again, check your results to check if you did it right.

# %%
ufo_vars.columns
# Out:
# Index(['year', 'month', 'state', 'country', 'ufo_shape', 'encounter_length'], dtype='object')

# %%
ufo_vars = ufo_vars.rename(columns = {'encounter_length': 'encounter_seconds'})

# %%
ufo_vars.columns
# Out:
# Index(['year', 'month', 'state', 'country', 'ufo_shape', 'encounter_seconds'], dtype='object')

# %% [markdown]
# ## Let's start filtering some records. Create a new dataframe called `ufo_us` and filter the `ufo_vars` dataframe bringing only the results in which the `country` is `"us"`

# %% [markdown]
# ### Use a mask to perform this task
#
# A `mask` is nothing more than a condition. This condition is applied to your whole dataframe (or pandas Series).
# So for example, if you had a pandas Series with a variable called `Age`, you could create a mask for all people whose `Age` is less than 18 years old using the syntax:
#
# `df['Age'] <= 18`
#
# This would return a pandas series containing `True` and `False` values. For each index, you'd get a value of `True` or `False`.
#
# You could save this mask in a variable, for example:
#
# `condition = (df['Age'] <= 18)`
#
# And then you could use that variable `condition` to select only the cases of the dataframe in which the index returned `True` using:
# df[condition].

# %%
ufo_vars['country'] == 'us'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 80327     True
# 80328     True
# 80329     True
# 80330     True
# 80331     True
# Name: country, Length: 80332, dtype: bool

# %%
mask = ufo_vars['country'] == 'us'

# %%
ufo_us = ufo_vars[mask]

# %%
ufo_us
# Out:
#        year  month state country ufo_shape  encounter_seconds
# 0      1949     10    tx      us  cylinder             2700.0
# 3      1956     10    tx      us    circle               20.0
# 4      1960     10    hi      us     light              900.0
# 5      1961     10    tn      us    sphere              300.0
# 7      1965     10    ct      us      disk             1200.0
# ...     ...    ...   ...     ...       ...                ...
# 80327  2013      9    tn      us     light              600.0
# 80328  2013      9    id      us    circle             1200.0
# 80329  2013      9    ca      us     other             1200.0
# 80330  2013      9    va      us    circle                5.0
# 80331  2013      9    ok      us     cigar             1020.0
#
# [65114 rows x 6 columns]

# %% [markdown]
# ### Use the .query() method to perform the same task
#
# Remember that the .query() method expects a string. That string should contain the variable of your dataframe without quotation marks and the comparison. For example, if you had a variable called `name`, you'd use a syntax like:
#  `df.query('name == "Jack"')`
#
# to bring all observations whose column `name` is exactly equal to `"Jack"` (note that Jack should be within quotation marks because a name is a string in this example).

# %%
ufo_vars.query('country == "us"')
# Out:
#        year  month state country ufo_shape  encounter_seconds
# 0      1949     10    tx      us  cylinder             2700.0
# 3      1956     10    tx      us    circle               20.0
# 4      1960     10    hi      us     light              900.0
# 5      1961     10    tn      us    sphere              300.0
# 7      1965     10    ct      us      disk             1200.0
# ...     ...    ...   ...     ...       ...                ...
# 80327  2013      9    tn      us     light              600.0
# 80328  2013      9    id      us    circle             1200.0
# 80329  2013      9    ca      us     other             1200.0
# 80330  2013      9    va      us    circle                5.0
# 80331  2013      9    ok      us     cigar             1020.0
#
# [65114 rows x 6 columns]

# %% [markdown]
# See which one do you prefer the most and keep using it for the exercises that follow

# %% [markdown]
# ## For the `ufo_us` dataframe, select only the cases in which the year is in the first decade (2001-2010). Put that in a variable called `ufo_us_2000`.
#
# Check your results.

# %%
#query
#ufo_us.query('year == "2001" ') 

#mask
#mask = ufo_vars['country'] == 'us' 
#ufo_us = ufo_vars[mask]
#ufo_us

mask_2001 = ufo_us['year']>=2001 
mask_2010 = ufo_us['year']<=2010
ufo_us_2000 = ufo_us[mask_2001 & mask_2010]
ufo_us_2000
# Out:
#        year  month state country  ufo_shape  encounter_seconds
# 102    2001     10    ia      us   triangle              240.0
# 105    2001     10    ca      us     circle              120.0
# 106    2001     10    ia      us  rectangle              300.0
# 107    2001     10    ca      us   changing              900.0
# 108    2001     10    az      us   triangle               60.0
# ...     ...    ...   ...     ...        ...                ...
# 80269  2010      9    mi      us   changing              300.0
# 80270  2010      9    fl      us       oval             2700.0
# 80271  2010      9    fl      us       oval             7200.0
# 80272  2010      9    nm      us   fireball              300.0
# 80273  2010      9    ca      us     circle              300.0
#
# [31910 rows x 6 columns]

# %% [markdown]
# ## Try to do the same without the intermediate step of creating the `ufo_us` dataframe. That is, try to filter the dataset for the cases in which the country is "us" and the year is (2001-2010)
#
#
#
# *Hint:* You have to make sure all of these conditions are applied simultaneously - using the `and` (or `&`) operator. Try to understand when to use the `and` and the `&` operator.

# %%
ufo_us_year = ufo[(ufo['country']=='us') & 
                        (ufo['year']>=2001) &
                        (ufo['year']<=2010)]

# %%
#ufo_us = ufo_vars[mask]

ufo_us_year
# Out:
#              date  year  month  day         date_time date_documented  \
# 102    2001-10-10  2001     10   10  10/10/2001 03:00        7/1/2002
# 105    2001-10-10  2001     10   10  10/10/2001 20:35      11/20/2001
# 106    2001-10-10  2001     10   10  10/10/2001 21:15      11/20/2001
# 107    2001-10-10  2001     10   10  10/10/2001 21:30      11/20/2001
# 108    2001-10-10  2001     10   10  10/10/2001 22:00      11/20/2001
# ...           ...   ...    ...  ...               ...             ...
# 80269  2010-09-09  2010      9    9    9/9/2010 21:30      11/21/2010
# 80270  2010-09-09  2010      9    9    9/9/2010 22:00      11/21/2010
# 80271  2010-09-09  2010      9    9    9/9/2010 22:00      11/21/2010
# 80272  2010-09-09  2010      9    9    9/9/2010 22:00      11/21/2010
# 80273  2010-09-09  2010      9    9    9/9/2010 23:19      11/21/2010
#
#            city_area state country  ufo_shape  encounter_length  \
# 102    rockwell city    ia      us   triangle             240.0
# 105          hayward    ca      us     circle             120.0
# 106          ottumwa    ia      us  rectangle             300.0
# 107           fresno    ca      us   changing             900.0
# 108          phoenix    az      us   triangle              60.0
# ...              ...   ...     ...        ...               ...
# 80269       brighton    mi      us   changing             300.0
# 80270    gainesville    fl      us       oval            2700.0
# 80271    gainesville    fl      us       oval            7200.0
# 80272        lemitar    nm      us   fireball             300.0
# 80273         upland    ca      us     circle             300.0
#
#       described_encounter_length  \
# 102                      4 min.s
# 105                       2/min.
# 106                  3-5 minutes
# 107                15 min. apprx
# 108           less then a minute
# ...                          ...
# 80269                3-5 minutes
# 80270                     45 min
# 80271                     2+ hrs
# 80272                3 to 5 mins
# 80273                    3-5 min
#
#                                              description   latitude  \
# 102    Large&#44silent&#44slow&#44low to the ground d...  42.395278
# 105    FALLING STAR  STOPS  &#39SHOTS OUT  DOZENS OF ...  37.668889
# 106    We saw a square object at night&#44  which had...  41.004167
# 107    Objects were sighted driving north on Highway ...  36.747778
# 108    Triangle shaped craft spotted flying west to e...  33.448333
# ...                                                  ...        ...
# 80269  Glittery random lights near each other&#44 rea...  42.529444
# 80270  2nd night watching the objects&#44 approximate...  29.651389
# 80271  Multiple sightings by multiple whitnesses&#44 ...  29.651389
# 80272  orange lights in the southeastern sky in New M...  34.159722
# 80273  It appeared to be an orange round object movin...  34.097500
#
#         longitude
# 102    -94.633611
# 105   -122.079722
# 106    -92.373611
# 107   -119.771389
# 108   -112.073333
# ...           ...
# 80269  -83.780278
# 80270  -82.325000
# 80271  -82.325000
# 80272 -106.909722
# 80273 -117.647500
#
# [31910 rows x 15 columns]

# %%
ufo_us

# %% [markdown]
# ## BONUS 1:  Compare the number of triangular UFO occurrances (checking the `ufo_shape` variable) in the US from the year 2001 up to 2010 as compared to the years of 1991 up to 2000.
#
# *Hint: you should expect roughly ~3 times more cases for 2001-2010 than 1991-2000.*

# %%
# calculate the dataframe from 2001-2010 here (Review later)
ufo_us['ufo_shape'].value_counts()['triangle']
# Out:
# 6549

# %%
# calculate the dataframe from 1991-2000 here (Review later)
condition1 = (ufo['year'] >= 1991)
condition2 = (ufo['year'] <= 2000)
condition3 = (ufo['country'] == 'us')
ufo_us_1990 = ufo[condition1 & condition2 & condition3]
ufo_us_1990['ufo_shape'].value_counts()['triangle']
# Out:
# 1116

# %% [markdown]
# How many rows does each dataset have?

# %% [markdown]
# ## BONUS 1.1: How many values does each category of `ufo_shape` has.

# %%
#Review later

ufo_us_1990['ufo_shape'].value_counts()
# Out:
# light        1660
# triangle     1116
# fireball      727
# other         721
# circle        638
# disk          605
# sphere        528
# unknown       510
# oval          334
# formation     265
# cigar         233
# changing      191
# cylinder      144
# chevron       143
# rectangle     138
# diamond       129
# flash         127
# egg           110
# teardrop       74
# cone           35
# cross          20
# delta           5
# round           2
# hexagon         1
# crescent        1
# pyramid         1
# changed         1
# flare           1
# Name: ufo_shape, dtype: int64

# %%
#Review later

ufo_us['ufo_shape'].value_counts()
# Out:
# light        13473
# triangle      6549
# circle        6118
# fireball      5148
# unknown       4567
# other         4466
# sphere        4347
# disk          4121
# oval          3032
# formation     1990
# cigar         1643
# changing      1584
# rectangle     1070
# flash         1062
# cylinder      1027
# diamond        928
# chevron        815
# teardrop       592
# egg            581
# cone           247
# cross          188
# delta            6
# round            2
# flare            1
# changed          1
# crescent         1
# hexagon          1
# pyramid          1
# Name: ufo_shape, dtype: int64

# %% [markdown]
# # Lab-Data-Manipulation (PART-2)

# %% [markdown]
# The second part of this lab consists of grouping and merging results.

# %% [markdown]
# # Grouping up the results.

# %% [markdown]
# ## Let's calculate the average of the encounter for each country.
#
# We should now group the results by the country column to see what is the mean encounter_seconds for each country. Do this using the `groupby` method of your dataframe `ufo_vars`. What is the average of the encounter for the us? And for Canada?
#
# Remember that after grouping by a column, you have to specify a `aggregating function`. If you don't do that, the results of the groupby will only be a `groupby` pandas object. For this case, we want the aggregating function to be the `mean` function and then the results will appear for us.
#
# Also remember that **if you don't** specify the `as_index=False` argument, the variables you use to group are going to become your new indexes.

# %%
ufo_vars = ufo[['year', 'month', 'state', 'country', 'ufo_shape', 'encounter_length']]
ufo_vars
# Out:
#        year  month state country ufo_shape  encounter_length
# 0      1949     10    tx      us  cylinder            2700.0
# 1      1949     10    tx     NaN     light            7200.0
# 2      1955     10   NaN      gb    circle              20.0
# 3      1956     10    tx      us    circle              20.0
# 4      1960     10    hi      us     light             900.0
# ...     ...    ...   ...     ...       ...               ...
# 80327  2013      9    tn      us     light             600.0
# 80328  2013      9    id      us    circle            1200.0
# 80329  2013      9    ca      us     other            1200.0
# 80330  2013      9    va      us    circle               5.0
# 80331  2013      9    ok      us     cigar            1020.0
#
# [80332 rows x 6 columns]

# %%
#ufo_vars.groupby(by=['country'], as_index=False).agg('mean')
ufo_vars.groupby('country', as_index=False).agg({'encounter_length':'mean'})
# Out:
#   country  encounter_length
# 0      au       3806.469238
# 1      ca      28859.437007
# 2      de      24255.980952
# 3      gb      66061.321207
# 4      us       5800.192049

# %%
ufo_vars.groupby(by=['country'], as_index=False).agg('mean')
# Out:
#   country         year     month  encounter_length
# 0      au  2002.693309  6.128253       3806.469238
# 1      ca  2003.694333  6.861667      28859.437007
# 2      de  2001.542857  6.247619      24255.980952
# 3      gb  2003.648294  6.562205      66061.321207
# 4      us  2004.090057  6.861597       5800.192049

# %% [markdown]
# ## Perform the same task, but instead of calculating the mean, count how many occurrances for each country.
#
# For this case, the aggregating function should be the `count` function. Try to understand the results for each column.

# %%
ufo_vars.groupby(by=['country']).count()
# Out:
#           year  month  state  ufo_shape  encounter_length
# country
# au         538    538     10        527               538
# ca        3000   3000   2985       2955              3000
# de         105    105      0        103               105
# gb        1905   1905     12       1855              1905
# us       65114  65114  65114      63561             65112

# %% [markdown]
# ## Perform the same task, but instead of calculating the mean, use the `.describe()` aggregating function to see the effects.
#
# The describe aggregating function will show you several important statistics for the grouped results, such as `mean`, `median`, `standard deviation`, `count`, `max`, `min`, and so on.
#
# *Hint: If it starts to get difficult to see the results, you can tranpose the resulting dataframe by just putting a `.T` at the end.*

# %%
ufo_vars.groupby(by=['country']).describe()
# Out:
#             year                                                          \
#            count         mean        std     min     25%     50%     75%
# country
# au         538.0  2002.693309   8.501768  1958.0  2001.0  2004.0  2007.0
# ca        3000.0  2003.694333   9.382976  1936.0  2002.0  2005.0  2010.0
# de         105.0  2001.542857  12.411245  1962.0  2000.0  2006.0  2009.0
# gb        1905.0  2003.648294   8.406754  1943.0  2002.0  2005.0  2009.0
# us       65114.0  2004.090057  10.385694  1910.0  2001.0  2007.0  2011.0
#
#                    month            ...             encounter_length  \
#             max    count      mean  ...   75%   max            count
# country                             ...
# au       2014.0    538.0  6.128253  ...   9.0  12.0            538.0
# ca       2014.0   3000.0  6.861667  ...   9.0  12.0           3000.0
# de       2014.0    105.0  6.247619  ...   8.0  12.0            105.0
# gb       2014.0   1905.0  6.562205  ...   9.0  12.0           1905.0
# us       2014.0  65114.0  6.861597  ...  10.0  12.0          65112.0
#
#
#                  mean           std   min   25%    50%    75%         max
# country
# au        3806.469238  5.434101e+04  0.50  30.0  180.0  600.0   1209600.0
# ca       28859.437007  1.511732e+06  0.02  20.0  120.0  600.0  82800000.0
# de       24255.980952  1.859988e+05  2.00  30.0  180.0  600.0   1814400.0
# gb       66061.321207  2.314714e+06  0.30  30.0  180.0  600.0  97836000.0
# us        5800.192049  4.045197e+05  0.01  30.0  180.0  600.0  66276000.0
#
# [5 rows x 24 columns]

# %%
#ufo_vars.groupby(by=['country']).describe().T
# Out:
# country                           au            ca            de  \
# year             count  5.380000e+02  3.000000e+03  1.050000e+02
#                  mean   2.002693e+03  2.003694e+03  2.001543e+03
#                  std    8.501768e+00  9.382976e+00  1.241125e+01
#                  min    1.958000e+03  1.936000e+03  1.962000e+03
#                  25%    2.001000e+03  2.002000e+03  2.000000e+03
#                  50%    2.004000e+03  2.005000e+03  2.006000e+03
#                  75%    2.007000e+03  2.010000e+03  2.009000e+03
#                  max    2.014000e+03  2.014000e+03  2.014000e+03
# month            count  5.380000e+02  3.000000e+03  1.050000e+02
#                  mean   6.128253e+00  6.861667e+00  6.247619e+00
#                  std    3.418689e+00  2.870414e+00  3.081524e+00
#                  min    1.000000e+00  1.000000e+00  1.000000e+00
#                  25%    3.000000e+00  5.000000e+00  4.000000e+00
#                  50%    6.000000e+00  7.000000e+00  6.000000e+00
#                  75%    9.000000e+00  9.000000e+00  8.000000e+00
#                  max    1.200000e+01  1.200000e+01  1.200000e+01
# encounter_length count  5.380000e+02  3.000000e+03  1.050000e+02
#                  mean   3.806469e+03  2.885944e+04  2.425598e+04
#                  std    5.434101e+04  1.511732e+06  1.859988e+05
#                  min    5.000000e-01  2.000000e-02  2.000000e+00
#                  25%    3.000000e+01  2.000000e+01  3.000000e+01
#                  50%    1.800000e+02  1.200000e+02  1.800000e+02
#                  75%    6.000000e+02  6.000000e+02  6.000000e+02
#                  max    1.209600e+06  8.280000e+07  1.814400e+06
#
# country                           gb            us
# year             count  1.905000e+03  6.511400e+04
#                  mean   2.003648e+03  2.004090e+03
#                  std    8.406754e+00  1.038569e+01
#                  min    1.943000e+03  1.910000e+03
#                  25%    2.002000e+03  2.001000e+03
#                  50%    2.005000e+03  2.007000e+03
#                  75%    2.009000e+03  2.011000e+03
#                  max    2.014000e+03  2.014000e+03
# month            count  1.905000e+03  6.511400e+04
#                  mean   6.562205e+00  6.861597e+00
#                  std    3.287748e+00  3.248243e+00
#                  min    1.000000e+00  1.000000e+00
#                  25%    4.000000e+00  4.000000e+00
#                  50%    7.000000e+00  7.000000e+00
#                  75%    9.000000e+00  1.000000e+01
#                  max    1.200000e+01  1.200000e+01
# encounter_length count  1.905000e+03  6.511200e+04
#                  mean   6.606132e+04  5.800192e+03
#                  std    2.314714e+06  4.045197e+05
#                  min    3.000000e-01  1.000000e-02
#                  25%    3.000000e+01  3.000000e+01
#                  50%    1.800000e+02  1.800000e+02
#                  75%    6.000000e+02  6.000000e+02
#                  max    9.783600e+07  6.627600e+07

# %%
#ufo_vars.describe()
# Out:
#                year         month  encounter_length
# count  80332.000000  80332.000000      8.032900e+04
# mean    2003.850085      6.834910      9.017226e+03
# std       10.426832      3.234863      6.202284e+05
# min     1906.000000      1.000000      1.000000e-03
# 25%     2001.000000      4.000000      3.000000e+01
# 50%     2006.000000      7.000000      1.800000e+02
# 75%     2011.000000      9.000000      6.000000e+02
# max     2014.000000     12.000000      9.783600e+07

# %% [markdown]
# ## Now, let's get deeper in the analysis and group the results not only by country. But by `country` and `year`

# %% [markdown]
# ### Check the values of the mean and count for the `encounter_seconds` variable for each year. Can you see some discrepancy?
#
# *Hint*: If you want, you can use the `ufo_us` dataset just to see the results for the united states. You could also (in a hacky way) perform the filter right before the groupby operation if you wanted.

# %%
#ufo_vars.groupby(by=['country','year'], as_index=False).agg('mean')

# %%
#review 'count'
ufo_vars.groupby(by=['country','year']).agg(['mean','count'])
# Out:
#                  month       encounter_length
#                   mean count             mean count
# country year
# au      1958  6.000000     1      2700.000000     1
#         1960  7.000000     1       180.000000     1
#         1967  1.000000     1       300.000000     1
#         1968  6.000000     1       300.000000     1
#         1972  5.666667     3       403.333333     3
# ...                ...   ...              ...   ...
# us      2010  7.114713  3548      2271.987232  3548
#         2011  7.298927  4379      2544.292555  4379
#         2012  7.024367  6320     10640.644916  6320
#         2013  7.469452  6056      1266.387888  6056
#         2014  2.566701  1964       782.372979  1964
#
# [282 rows x 4 columns]

# %% [markdown]
# # BONUS 2: Which months are the ones with the highest numbers of occurrences?

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-0f82ab7a50f5> in <module>
# ----> 1 ufo_vars.groupby(by=['country', 'month']).agg(count_seconds = ('encounter_seconds' , 'count'))
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     414                         nested_renaming_depr()
#     415                     elif isinstance(obj, ABCDataFrame) and k not in obj.columns:
# --> 416                         raise KeyError("Column '{col}' does not exist!".format(col=k))
#     417
#     418                 arg = new_arg
#
# KeyError: "Column 'encounter_seconds' does not exist!"

# %% [markdown]
# # BONUS 3: Finally, you gathered information about the UFO dataset. Using your last result, try to bring that information for your original dataset.

# %% [markdown]
# 1. Store the results of your previous analysis (the mean value for the encounter_seconds for each year and each country) in a dataframe called `avg_results`.

# %% [markdown]
# 2. Rename the column named `encounter_seconds` to `avg_encounter_seconds`.

# %% [markdown]
# 3. Use the pd.merge( ... ) function to bring that new collected information to your original dataset.
# The pd.merge() function requires several arguments, let's understand the most important ones.
#
# `left` is the dataframe you want to bring information **to** - the table on the left. In this case, this will be our original dataframe called `ufo`
#
# `right` is the dataframe you want to bring information **from** - the table on the right. In this case, this will be our resulting dataframe `avg_results`.
#
# `on` is the key you want to perform the merge. That is, if those values are **exactly equal** in both dataframes, then the information will be brought.
#
# Put your results on a dataframe called `merged_ufo`

# %% [markdown]
# Check how many rows the final result has and try to explain it. Did the dataset get smaller? Bigger? Or the same? Can you explain why?
#
# *hint: If you've found something weird, try looking back at your original dataframe and find something interesting on it.*

# %% [markdown]
# ## Store the results into a new csv file called `ufo_enriched.csv`.
#
# Don't forget to use `index=False`.
